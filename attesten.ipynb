# %%
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model

df_all = pd.read_csv('data.csv', delimiter=",")
df_all = df_all.rename(columns = {
    'Naam kind': 'naam', 
    'Voornaam kind': 'voornaam', 
    'Mijn kind is onderdeel van': 'groep',
    'Geboortedatum kind':'geboortedatum',
    'Mijn kind ging x aantal dagen mee op kamp in 2021' : 'kampdagen',
    'Mijn kind ging mee op weekend in 2021': 'weekend',
    'Emailadres waar wij het attest naar terugmailen': 'email'
})

df_hito = df_all[df_all.groep == 'Chiro Hito (meisjes)']
df_sjima = df_all[df_all.groep == 'Chiro Sjima (jongens)']

df_hito.head()
# Out:
#            Tijdstempel        naam  voornaam                 groep  \
# 1   10-5-2022 19:42:17    Weytens     Ylena   Chiro Hito (meisjes)
# 2   10-5-2022 19:44:17  Lammertijn     Floor  Chiro Hito (meisjes)
# 5   10-5-2022 19:49:09      Dubois     Hanne  Chiro Hito (meisjes)
# 7   10-5-2022 20:05:15      Demoor      Gail  Chiro Hito (meisjes)
# 11  10-5-2022 20:16:58       Clara  Neirynck  Chiro Hito (meisjes)
#
#    geboortedatum  kampdagen weekend                             email
# 1      29-1-2012         10     nee       coussement_nele@hotmail.com
# 2      31-1-2009         10     nee        lydia_neirynck@hotmail.com
# 5      22-6-2012         10      ja            ellenroose@hotmail.com
# 7      8-11-2014          5      ja       Veerle.Verleyen2@telenet.be
# 11    10-12-2013          5      ja  anneleenvanderiviere@hotmail.com

# %%
df_sjima.head()
# Out:
#           Tijdstempel        naam voornaam                  groep  \
# 0  10-5-2022 19:35:04   Notteboom      Ian  Chiro Sjima (jongens)
# 3  10-5-2022 19:44:55  Lammertijn      Vic  Chiro Sjima (jongens)
# 4  10-5-2022 19:47:28      Dubois    Warre  Chiro Sjima (jongens)
# 6  10-5-2022 19:59:07     Tournet   Ayden   Chiro Sjima (jongens)
# 8  10-5-2022 20:06:49  Verleysen    Niels   Chiro Sjima (jongens)
#
#   geboortedatum  kampdagen weekend                       email
# 0    24-10-2014          5     nee    renoultkatinka@gmail.com
# 3    16-10-2010         10     nee  lydia_neirynck@hotmail.com
# 4     12-2-2009         10      ja      Ellenroose@hotmail.com
# 6     11-3-2015          5      ja       Kimtournet@outlook.be
# 8     3-12-2007         10      ja   Evelyne.lippens@gmail.com
